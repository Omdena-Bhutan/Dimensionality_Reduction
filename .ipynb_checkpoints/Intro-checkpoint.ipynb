# %% [markdown]
# ## Dimensionality Reduction
# - Data Preprocessing technique used to reduce the number of input features (Dimensions) in a dataset while keeping as much important information as possible
#
# ### WHY?
# - Reduces overfitting
# - Improves the model performance
# - Handles the curse of dimensionality
# - Helps in data visualization
#
# ## 2 Main types
# ### 1. Feature Selection
# - You keep the original Features, but remove unimportant ones
# ### 2. Feature Extraction
# - Create new features by combining the existing ones

# %% [markdown]
# # Dimensionalty Reduction
# - Wine Dataset

# %%
# set up the env
! pip install pandas numpy scikit-learn matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in d:\data\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\admin\appdata\roaming\python\python312\site-packages (1.26.0)
# Requirement already satisfied: scikit-learn in d:\data\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in d:\data\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\data\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in d:\data\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\data\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\data\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\data\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\data\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\data\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\data\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\data\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\admin\appdata\roaming\python\python312\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\data\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in d:\data\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from sklearn.datasets import load_wine
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load teh wine dataset 
wine = load_wine()

# %%
# Create a dataframe
X = pd.DataFrame(wine.data, columns = wine.feature_names)
y = wine.target

# %%
print(X.head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
print("Shape:", X.shape)
# Out:
# Shape: (178, 13)

# %% [markdown]
# # Goal
# - Reduce the 13 -> 2 dimensions

# %%
# Standardize
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Principal Component Analysis

# %%
from sklearn.decomposition import PCA

# Reduce dimension to 2
pca = PCA(n_components = 2)

X_pca = pca.fit_transform(X_scaled)

print("Original Shape:", X.shape)
print("Reduced Shape:", X_pca.shape)
# Out:
# Original Shape: (178, 13)
# Reduced Shape: (178, 2)

# %% [markdown]
# ### How much information did we keep?

# %%
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
print("Total variance retained: ", sum(pca.explained_variance_ratio_))
# Out:
# Explained Variance Ratio: [0.36198848 0.1920749 ]
# Total variance retained:  0.5540633835693526

# %% [markdown]
# ## Visualize the reduced data

# %%
plt.figure(figsize = (8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c = y)
plt.xlabel("Principal component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA of wine Dataset")
plt.colorbar(label = "Wine Class")
plt.show()

# %% [markdown]
# ## How many components do we really need?

# %%
pca_full = PCA()
pca_full.fit(X_scaled)
# Out:
# PCA()

# %%
plt.plot(pca_full.explained_variance_ratio_.cumsum(), marker='o')
plt.xlabel("Number of components")
plt.ylabel("Cummulative explained Variance")
plt.title("Explained Varaincevs components")
plt.grid()
plt.show()

# %% [markdown]
# ## PCA + ML

# %%
from sklearn.linear_model import LogisticRegression

# %%
pca = PCA(n_components = 6)
X_reduced = pca.fit_transform(X_scaled)

model = LogisticRegression(max_iter = 200)
model.fit(X_reduced, y)

print("Model trained with reduced dimensions")
# Out:
# Model trained with reduced dimensions

# %% [markdown]
# # Assignment - Task
# 1. Research the Mathematics behind PCA and the intuition
# 2. Compare PCA vs t-SNE vs UMAP (Make sure to have a visual intuition)
# 3. Implement the PCA inside the sklearn pipeline
# 4. Perform a dimensionality reduction for images - use food 101 images dataset: https://www.kaggle.com/datasets/kmader/food41
#
# Make commits to your GitHub branch in this dimensionality reduction
